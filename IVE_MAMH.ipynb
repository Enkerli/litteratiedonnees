# %% [markdown]
# <a href="https://colab.research.google.com/github/Enkerli/litteratiedonnees/blob/main/IVE_MAMH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series
from bs4 import BeautifulSoup
from IPython.display import HTML
#from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#ive2016=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2016_ISQ-MAMH.xlsx?raw=true", index_col='Nom de la localité et statut juridique')
#ive2016.index.rename('Nom', inplace=True)
ive2016=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2016_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2016.index.rename(('Nom', 'Region'), inplace=True)
ive2016.drop(columns='Unnamed: 7', inplace=True)
ive2016.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2016['Quintile']=pd.qcut(ive2016['Rang'], q=5, labels=False)+1
#ive2016.rename(columns={'Rang':'Rang2016'}, inplace=True)
ive2016=ive2016.add_suffix('_2016')

ive2014=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2014_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2014.index.rename(('Nom', 'Region'), inplace=True)
ive2014.drop(columns='Unnamed: 7', inplace=True)
ive2014.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2014['Quintile']=pd.qcut(ive2014['Rang'], q=5, labels=False)+1
ive2014=ive2014.add_suffix('_2014')

ive2002=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2002_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2002.index.rename(('Nom', 'Region'), inplace=True)
#ive2002.drop(columns='Unnamed: 7', inplace=True)
ive2002.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2002['Quintile']=pd.qcut(ive2002['Rang'], q=5, labels=False)+1
ive2002=ive2002.add_suffix('_2002')

ive2003=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2003_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2003.index.rename(('Nom', 'Region'), inplace=True)
ive2003.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2003['Quintile']=pd.qcut(ive2003['Rang'], q=5, labels=False)+1
ive2003=ive2003.add_suffix('_2003')

ive2004=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2004_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2004.index.rename(('Nom', 'Region'), inplace=True)
ive2004.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu',
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2004['Quintile']=pd.qcut(ive2004['Rang'], q=5, labels=False)+1
ive2004=ive2004.add_suffix('_2004')

ive2005=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2005_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2005.index.rename(('Nom', 'Region'), inplace=True)
ive2005.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2005['Quintile']=pd.qcut(ive2005['Rang'], q=5, labels=False)+1
ive2005=ive2005.add_suffix('_2005')

ive2006=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2006_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2006.index.rename(('Nom', 'Region'), inplace=True)
ive2006.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2006['Quintile']=pd.qcut(ive2006['Rang'], q=5, labels=False)+1
ive2006=ive2006.add_suffix('_2006')

ive2007=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2007_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2007.index.rename(('Nom', 'Region'), inplace=True)
ive2007.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2007['Quintile']=pd.qcut(ive2007['Rang'], q=5, labels=False)+1
ive2007=ive2007.add_suffix('_2007')

ive2008=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2008_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2008.index.rename(('Nom', 'Region'), inplace=True)
ive2008.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2008['Quintile']=pd.qcut(ive2008['Rang'], q=5, labels=False)+1
ive2008=ive2008.add_suffix('_2008')

ive2009=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2009_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2009.index.rename(('Nom', 'Region'), inplace=True)
ive2009.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2009['Quintile']=pd.qcut(ive2009['Rang'], q=5, labels=False)+1
ive2009=ive2009.add_suffix('_2009')

ive2010=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2010_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2010.index.rename(('Nom', 'Region'), inplace=True)
ive2010.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2010['Quintile']=pd.qcut(ive2010['Rang'], q=5, labels=False)+1
ive2010=ive2010.add_suffix('_2010')

ive2011=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2011_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2011.index.rename(('Nom', 'Region'), inplace=True)
ive2011.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2011['Quintile']=pd.qcut(ive2011['Rang'], q=5, labels=False)+1
ive2011=ive2011.add_suffix('_2011')

ive2012=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2012_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2012.index.rename(('Nom', 'Region'), inplace=True)
ive2012.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2012['Quintile']=pd.qcut(ive2012['Rang'], q=5, labels=False)+1
ive2012=ive2012.add_suffix('_2012')

ive2013=pd.read_excel("https://github.com/Enkerli/litteratiedonnees/blob/main/IVE2013_ISQ-MAMH.xlsx?raw=true", index_col=(1,2))
ive2013.index.rename(('Nom', 'Region'), inplace=True)
ive2013.rename(columns={'Indice de vitalité économique (n)': 'IVE', 'Revenu total médian des particuliers de 18 ans et plus ($)': 'Revenu', 
                        'TAAM de la population sur 5 ans (pour mille)': 'TAAM', 'Taux de travailleurs des 25-64 ans (%)': 'Travailleurs'}, inplace=True)
ive2013['Quintile']=pd.qcut(ive2013['Rang'], q=5, labels=False)+1
ive2013=ive2013.add_suffix('_2013')

#ive=pd.merge(left=ive2002, right=ive2003, on='Nom')
ive=pd.merge(left=ive2002, right=ive2003, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2004, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2005, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2006, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2007, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2008, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2009, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2010, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2011, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2012, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2013, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2014, on=('Nom','Region'))
ive=pd.merge(left=ive, right=ive2016, on=('Nom','Region'))
#ive.loc[:, ive.columns.str.startswith("Quint")]
ive
# Out:
#                                                                             Rang_2002  ...  Quintile_2016
# Nom                                          Region                                    ...
# Lac-Saint-Joseph (V)                         Capitale-Nationale                     1  ...              1
# Lac-Delage (V)                               Capitale-Nationale                     2  ...              1
# Notre-Dame-de-l'Île-Perrot (V)               Montérégie                             3  ...              1
# Blainville (V)                               Laurentides                            4  ...              1
# Saint-Lazare (V)                             Montérégie                             5  ...              1
# ...                                                                               ...  ...            ...
# L'Ascension-de-Patapédia (M)                 Gaspésie–Îles-de-la-Madeleine       1036  ...              5
# ...

# %%
ive['Qdif03']=np.where(ive['Quintile_2002']==ive['Quintile_2003'],0, 1)
ive['Qdif04']=np.where(ive['Quintile_2003']==ive['Quintile_2004'],0, 1)
ive['Qdif05']=np.where(ive['Quintile_2004']==ive['Quintile_2005'],0, 1)
ive['Qdif06']=np.where(ive['Quintile_2005']==ive['Quintile_2006'],0, 1)
ive['Qdif07']=np.where(ive['Quintile_2006']==ive['Quintile_2007'],0, 1)
ive['Qdif08']=np.where(ive['Quintile_2007']==ive['Quintile_2008'],0, 1)
ive['Qdif09']=np.where(ive['Quintile_2008']==ive['Quintile_2009'],0, 1)
ive['Qdif10']=np.where(ive['Quintile_2009']==ive['Quintile_2010'],0, 1)
ive['Qdif11']=np.where(ive['Quintile_2010']==ive['Quintile_2011'],0, 1)
ive['Qdif12']=np.where(ive['Quintile_2011']==ive['Quintile_2012'],0, 1)
ive['Qdif13']=np.where(ive['Quintile_2012']==ive['Quintile_2013'],0, 1)
ive['Qdif14']=np.where(ive['Quintile_2013']==ive['Quintile_2014'],0, 1)
ive['Qdif16']=np.where(ive['Quintile_2014']==ive['Quintile_2016'],0, 1)
ive['QuintDif']=ive['Qdif03']+ive['Qdif04']+ive['Qdif05']+ive['Qdif06']+ive['Qdif07']+ive['Qdif08']+ive['Qdif09']+ive['Qdif10']+ive['Qdif11']+ive['Qdif12']+ive['Qdif13']+ive['Qdif14']+ive['Qdif16']
#ive.sort_values(by='QuintDif', ascending=False)
#ive.loc[:,ive.columns.str.startswith("Quint")].sort_values(by='QuintDif', ascending=False)

# %%
ive['QuintDif'].sort_values(ascending=False)
# Out:
# Nom                             Region
# Saint-Onésime-d'Ixworth (M)     Bas-Saint-Laurent       9
# Saint-Camille (CT)              Estrie                  8
# Lawrenceville (VL)              Estrie                  8
# Sheenboro (M)                   Outaouais               8
# Fortierville (M)                Centre-du-Québec        8
#                                                        ..
# Saint-Germain-de-Grantham (M)   Centre-du-Québec        0
# L'Assomption (V)                Lanaudière              0
# Sainte-Martine (M)              Montérégie              0
# Sainte-Lucie-de-Beauregard (M)  Chaudière-Appalaches    0
# Saint-Jean-de-Cherbourg (P)     Bas-Saint-Laurent       0
# Name: QuintDif, Length: 941, dtype: int64

# %%
ive['Quintile_2002'].loc[ive['QuintDif']==0]
# Out:
# Nom                                           Region
# Lac-Delage (V)                                Capitale-Nationale               1
# Notre-Dame-de-l'Île-Perrot (V)                Montérégie                       1
# Blainville (V)                                Laurentides                      1
# Saint-Lazare (V)                              Montérégie                       1
# Cantley (M)                                   Outaouais                        1
#                                                                               ..
# L'Ascension-de-Patapédia (M)                  Gaspésie–Îles-de-la-Madeleine    5
# Sainte-Madeleine-de-la-Rivière-Madeleine (M)  Gaspésie–Îles-de-la-Madeleine    5
# Cloridorme (CT)                               Gaspésie–Îles-de-la-Madeleine    5
# Saint-Guy (M)                                 Bas-Saint-Laurent                5
# Saint-Jean-de-Cherbourg (P)                   Bas-Saint-Laurent                5
# ...

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==1)]
# Out:
# Nom                             Region
# Lac-Delage (V)                  Capitale-Nationale    1
# Notre-Dame-de-l'Île-Perrot (V)  Montérégie            1
# Blainville (V)                  Laurentides           1
# Saint-Lazare (V)                Montérégie            1
# Cantley (M)                     Outaouais             1
#                                                      ..
# Brossard (V)                    Montérégie            1
# Beloeil (V)                     Montérégie            1
# La Présentation (M)             Montérégie            1
# Québec (V)                      Capitale-Nationale    1
# Saint-Amable (V)                Montérégie            1
# Name: Quintile_2002, Length: 108, dtype: int64

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==5)]
# Out:
# Nom                                           Region
# Saint-Juste-du-Lac (M)                        Bas-Saint-Laurent                5
# Mont-Albert (NO)                              Gaspésie–Îles-de-la-Madeleine    5
# Saint-Léon-le-Grand (P)                       Bas-Saint-Laurent                5
# Chute-aux-Outardes (VL)                       Côte-Nord                        5
# Padoue (M)                                    Bas-Saint-Laurent                5
#                                                                               ..
# L'Ascension-de-Patapédia (M)                  Gaspésie–Îles-de-la-Madeleine    5
# Sainte-Madeleine-de-la-Rivière-Madeleine (M)  Gaspésie–Îles-de-la-Madeleine    5
# Cloridorme (CT)                               Gaspésie–Îles-de-la-Madeleine    5
# Saint-Guy (M)                                 Bas-Saint-Laurent                5
# Saint-Jean-de-Cherbourg (P)                   Bas-Saint-Laurent                5
# ...

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==5) & (ive.index.get_level_values(level=1).str.contains("Sag"))]
# Out:
# Nom                      Region
# Lac-Bouchette (M)        Saguenay–Lac-Saint-Jean    5
# Petit-Saguenay (M)       Saguenay–Lac-Saint-Jean    5
# Saint-Thomas-Didyme (M)  Saguenay–Lac-Saint-Jean    5
# Name: Quintile_2002, dtype: int64

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==1) & (ive.index.get_level_values(level=1).str.contains("Sag"))]
# Out:
# Series([], Name: Quintile_2002, dtype: int64)

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==2) & (ive.index.get_level_values(level=1).str.contains("Sag"))]
# Out:
# Series([], Name: Quintile_2002, dtype: int64)

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==3) & (ive.index.get_level_values(level=1).str.contains("Sag"))]
# Out:
# Nom                 Region
# Saint-Félicien (V)  Saguenay–Lac-Saint-Jean    3
# Name: Quintile_2002, dtype: int64

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==4) & (ive.index.get_level_values(level=1).str.contains("Sag"))]
# Out:
# Nom                     Region
# Roberval (V)            Saguenay–Lac-Saint-Jean    4
# Dolbeau-Mistassini (V)  Saguenay–Lac-Saint-Jean    4
# Name: Quintile_2002, dtype: int64

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive.index.get_level_values(level=1).str.contains("Sag"))].sort_values()
# Out:
# Nom                      Region
# Saint-Félicien (V)       Saguenay–Lac-Saint-Jean    3
# Roberval (V)             Saguenay–Lac-Saint-Jean    4
# Dolbeau-Mistassini (V)   Saguenay–Lac-Saint-Jean    4
# Lac-Bouchette (M)        Saguenay–Lac-Saint-Jean    5
# Petit-Saguenay (M)       Saguenay–Lac-Saint-Jean    5
# Saint-Thomas-Didyme (M)  Saguenay–Lac-Saint-Jean    5
# Name: Quintile_2002, dtype: int64

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']>5) & (ive.index.get_level_values(level=1).str.contains("Sag"))].sort_values()
# Out:
# Nom                      Region
# Sainte-Rose-du-Nord (P)  Saguenay–Lac-Saint-Jean    4
# Name: Quintile_2002, dtype: int64

# %%
ive.loc[ive.index.get_level_values(level=0).str.contains("Rose-du"), ive.columns.str.startswith("Quint")] # Le Bonheur de Pierre est sorti en 2009
# Out:
#                                                  Quintile_2002  ...  QuintDif
# Nom                     Region                                  ...
# Sainte-Rose-du-Nord (P) Saguenay–Lac-Saint-Jean              4  ...         6
#
# [1 rows x 15 columns]

# %%
ive['Quintile_2002'].loc[(ive['QuintDif']==0) & (ive['Quintile_2002']==5)].sort_index(level='Region', ascending=False)
# Out:
# Nom                        Region
# Saint-Thomas-Didyme (M)    Saguenay–Lac-Saint-Jean    5
# Petit-Saguenay (M)         Saguenay–Lac-Saint-Jean    5
# Lac-Bouchette (M)          Saguenay–Lac-Saint-Jean    5
# Saint-Joseph-de-Sorel (V)  Montérégie                 5
# Lac-du-Cerf (M)            Laurentides                5
#                                                      ..
# Rémigny (M)                Abitibi-Témiscamingue      5
# Rochebaucourt (M)          Abitibi-Témiscamingue      5
# Normétal (M)               Abitibi-Témiscamingue      5
# Latulipe-et-Gaboury (CU)   Abitibi-Témiscamingue      5
# La Morandière (M)          Abitibi-Témiscamingue      5
# Name: Quintile_2002, Length: 79, dtype: int64

# %%
ive.loc[ive.index.get_level_values(level=1).str.contains("Sag")].reindex(columns=['QuintDif', 'Quintile_2002', 'Quintile_2016']).sort_values(by='Nom')
# Out:
#                                                             QuintDif  ...  Quintile_2016
# Nom                                Region                             ...
# Albanel (M)                        Saguenay–Lac-Saint-Jean         1  ...              3
# Alma (V)                           Saguenay–Lac-Saint-Jean         2  ...              3
# Bégin (M)                          Saguenay–Lac-Saint-Jean         2  ...              4
# Chambord (M)                       Saguenay–Lac-Saint-Jean         1  ...              3
# Desbiens (V)                       Saguenay–Lac-Saint-Jean         1  ...              4
# Dolbeau-Mistassini (V)             Saguenay–Lac-Saint-Jean         0  ...              4
# Ferland-et-Boilleau (M)            Saguenay–Lac-Saint-Jean         2  ...              4
# Girardville (M)                    Saguenay–Lac-Saint-Jean         2  ...              4
# Hébertville (M)                    Saguenay–Lac-Saint-Jean         4  ...              3
# ...
